# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
history_root = "/nas/home/cborrelli/tripletloss_bot/history"
history_filename = "model_classes_-_A01_A02_A03_A04_A05_A06_epochs_1000_steps_per_epoch_100.npy"
history = np.load(os.path.join(history_root, history_filename), allow_pickle=True)
history = history.item()

# %%
plt.figure(figsize=(15,10))
plt.grid(True)
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
